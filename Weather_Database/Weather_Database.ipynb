# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import os
import json
from pprint import pprint
import time
from datetime import datetime

from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv('weather_api_key')
type(weather_api_key)
# Out:
# str

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9264b6b72d38574591451900e75333f8

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
  # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | zhigansk
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | mahdasht
# Processing Record 6 of Set 1 | konstantinovka
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | marsa matruh
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | leningradskiy
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | kavaratti
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | paita
# Processing Record 18 of Set 1 | egvekinot
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | kununurra
# Processing Record 21 of Set 1 | dalhousie
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | mihijam
# Processing Record 24 of Set 1 | edd
# Processing Record 25 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | gladstone
# Processing Record 29 of Set 1 | samana
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | nishihara
# Processing Record 35 of Set 1 | anadyr
# Processing Record 36 of Set 1 | san matias
# Processing Record 37 of Set 1 | maroantsetra
# Processing Record 38 of Set 1 | comodoro rivadavia
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | gavle
# Processing Record 44 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 1 | doha
# Processing Record 46 of Set 1 | tiarei
# Processing Record 47 of Set 1 | sitka
# Processing Record 48 of Set 1 | itarema
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | borovoy
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | fort-shevchenko
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | conde
# Processing Record 6 of Set 2 | walvis bay
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | chegdomyn
# Processing Record 9 of Set 2 | bronnoysund
# Processing Record 10 of Set 2 | abu kamal
# Processing Record 11 of Set 2 | were ilu
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | havelock
# Processing Record 14 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | alice town
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | cairns
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | kalanguy
# Processing Record 26 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | nome
# Processing Record 30 of Set 2 | lakes entrance
# Processing Record 31 of Set 2 | gizo
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | bella union
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | baoro
# Processing Record 37 of Set 2 | oksfjord
# Processing Record 38 of Set 2 | melbu
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | netivot
# Processing Record 41 of Set 2 | trat
# Processing Record 42 of Set 2 | moose factory
# Processing Record 43 of Set 2 | vostok
# Processing Record 44 of Set 2 | emirdag
# Processing Record 45 of Set 2 | sorland
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | bonthe
# Processing Record 49 of Set 2 | obo
# Processing Record 50 of Set 2 | santa maria
# Processing Record 1 of Set 3 | la ronge
# Processing Record 2 of Set 3 | kirakira
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | noshiro
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | petawawa
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | port augusta
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | frontera
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | moosomin
# Processing Record 19 of Set 3 | ballina
# Processing Record 20 of Set 3 | kuching
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 3 | jumla
# Processing Record 24 of Set 3 | birao
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | evensk
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | bowen
# Processing Record 30 of Set 3 | mareeba
# Processing Record 31 of Set 3 | tabuk
# Processing Record 32 of Set 3 | robertsport
# Processing Record 33 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 3 | santa isabel do rio negro
# Processing Record 35 of Set 3 | dipkarpaz
# City not found. Skipping...
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | tessalit
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | atbasar
# Processing Record 41 of Set 3 | dauphin
# Processing Record 42 of Set 3 | kristiinankaupunki
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | san quintin
# Processing Record 45 of Set 3 | niquelandia
# Processing Record 46 of Set 3 | sobolevo
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | nanakuli
# Processing Record 50 of Set 3 | morwell
# Processing Record 1 of Set 4 | tomatlan
# Processing Record 2 of Set 4 | fuyang
# Processing Record 3 of Set 4 | baherden
# Processing Record 4 of Set 4 | zhoukou
# Processing Record 5 of Set 4 | bontang
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | mahajanga
# Processing Record 10 of Set 4 | kabalo
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | ilula
# Processing Record 13 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 4 | marabba
# Processing Record 15 of Set 4 | ust-kuyga
# Processing Record 16 of Set 4 | erenhot
# Processing Record 17 of Set 4 | jamestown
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | haines junction
# Processing Record 22 of Set 4 | new norfolk
# Processing Record 23 of Set 4 | shestakovo
# Processing Record 24 of Set 4 | hirara
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | ponta delgada
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | birin
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | quincy
# Processing Record 31 of Set 4 | tarakan
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | kribi
# Processing Record 34 of Set 4 | port macquarie
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | fort nelson
# Processing Record 37 of Set 4 | staunton
# Processing Record 38 of Set 4 | sao raimundo das mangabeiras
# Processing Record 39 of Set 4 | clinton
# Processing Record 40 of Set 4 | tromso
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | san borja
# Processing Record 43 of Set 4 | yelizovo
# Processing Record 44 of Set 4 | christchurch
# Processing Record 45 of Set 4 | ahipara
# Processing Record 46 of Set 4 | novaya igirma
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | bam
# Processing Record 49 of Set 4 | sao felix do xingu
# Processing Record 50 of Set 4 | sungai kolok
# City not found. Skipping...
# Processing Record 1 of Set 5 | pochutla
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | rio brilhante
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | zalantun
# Processing Record 6 of Set 5 | vestmannaeyjar
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | san cristobal
# Processing Record 10 of Set 5 | amazar
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | tucumcari
# Processing Record 15 of Set 5 | keshan
# City not found. Skipping...
# Processing Record 16 of Set 5 | teguldet
# Processing Record 17 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 5 | raudeberg
# Processing Record 20 of Set 5 | atuona
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | ouallam
# Processing Record 23 of Set 5 | kandrian
# Processing Record 24 of Set 5 | roald
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | svetlogorsk
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | lamphun
# Processing Record 29 of Set 5 | schneverdingen
# Processing Record 30 of Set 5 | lebane
# Processing Record 31 of Set 5 | pareora
# Processing Record 32 of Set 5 | sao desiderio
# Processing Record 33 of Set 5 | semey
# Processing Record 34 of Set 5 | khandyga
# Processing Record 35 of Set 5 | muros
# Processing Record 36 of Set 5 | fortuna
# Processing Record 37 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 5 | richards bay
# Processing Record 39 of Set 5 | coahuayana
# Processing Record 40 of Set 5 | baruun-urt
# Processing Record 41 of Set 5 | yichang
# Processing Record 42 of Set 5 | arlit
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | catuday
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | umm lajj
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | angoche
# Processing Record 49 of Set 5 | mount pleasant
# Processing Record 50 of Set 5 | port blair
# Processing Record 1 of Set 6 | shingu
# Processing Record 2 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | east london
# Processing Record 6 of Set 6 | vallenar
# Processing Record 7 of Set 6 | ipixuna
# Processing Record 8 of Set 6 | washington
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 6 | jaisalmer
# Processing Record 12 of Set 6 | luwuk
# Processing Record 13 of Set 6 | marienburg
# Processing Record 14 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 6 | warrnambool
# Processing Record 16 of Set 6 | gigmoto
# Processing Record 17 of Set 6 | cayenne
# Processing Record 18 of Set 6 | lavrentiya
# Processing Record 19 of Set 6 | sfantu gheorghe
# Processing Record 20 of Set 6 | ambon
# Processing Record 21 of Set 6 | harper
# Processing Record 22 of Set 6 | horsham
# Processing Record 23 of Set 6 | katobu
# Processing Record 24 of Set 6 | riyadh
# Processing Record 25 of Set 6 | nizhniy kuranakh
# Processing Record 26 of Set 6 | kimberley
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | mwense
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | cabedelo
# Processing Record 32 of Set 6 | florian
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | novovasylivka
# Processing Record 36 of Set 6 | chalons-en-champagne
# Processing Record 37 of Set 6 | yamada
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | ulladulla
# Processing Record 40 of Set 6 | sawtell
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | manado
# Processing Record 44 of Set 6 | oktyabrskoye
# Processing Record 45 of Set 6 | anzhero-sudzhensk
# Processing Record 46 of Set 6 | hovd
# Processing Record 47 of Set 6 | sawakin
# Processing Record 48 of Set 6 | kidal
# Processing Record 49 of Set 6 | saldanha
# Processing Record 50 of Set 6 | la macarena
# Processing Record 1 of Set 7 | peniche
# Processing Record 2 of Set 7 | umm kaddadah
# Processing Record 3 of Set 7 | matagami
# Processing Record 4 of Set 7 | caluquembe
# Processing Record 5 of Set 7 | padang
# Processing Record 6 of Set 7 | quatre cocos
# Processing Record 7 of Set 7 | san rafael
# Processing Record 8 of Set 7 | lac du bonnet
# Processing Record 9 of Set 7 | alta floresta
# Processing Record 10 of Set 7 | orcopampa
# Processing Record 11 of Set 7 | santa cruz
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | bilma
# Processing Record 14 of Set 7 | rio gallegos
# Processing Record 15 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 16 of Set 7 | sao joao da barra
# Processing Record 17 of Set 7 | nalut
# Processing Record 18 of Set 7 | ottawa
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | nanortalik
# Processing Record 21 of Set 7 | north myrtle beach
# Processing Record 22 of Set 7 | yellowknife
# Processing Record 23 of Set 7 | phan thiet
# Processing Record 24 of Set 7 | mantua
# Processing Record 25 of Set 7 | colorado springs
# Processing Record 26 of Set 7 | pacific grove
# Processing Record 27 of Set 7 | araguacu
# Processing Record 28 of Set 7 | ajdabiya
# Processing Record 29 of Set 7 | whitehorse
# Processing Record 30 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 31 of Set 7 | mazagao
# Processing Record 32 of Set 7 | zaysan
# Processing Record 33 of Set 7 | husavik
# Processing Record 34 of Set 7 | niagara falls
# Processing Record 35 of Set 7 | kochubey
# Processing Record 36 of Set 7 | znamenskoye
# Processing Record 37 of Set 7 | parakai
# Processing Record 38 of Set 7 | kiunga
# Processing Record 39 of Set 7 | monteagudo
# Processing Record 40 of Set 7 | grand gaube
# Processing Record 41 of Set 7 | mabaruma
# Processing Record 42 of Set 7 | yanam
# Processing Record 43 of Set 7 | panzhihua
# Processing Record 44 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 7 | sabratah
# Processing Record 46 of Set 7 | bonavista
# Processing Record 47 of Set 7 | liepaja
# Processing Record 48 of Set 7 | lima
# Processing Record 49 of Set 7 | stephenville
# Processing Record 50 of Set 7 | labuhan
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | paraiso
# Processing Record 3 of Set 8 | kailua
# Processing Record 4 of Set 8 | den helder
# Processing Record 5 of Set 8 | ormara
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | salalah
# Processing Record 8 of Set 8 | aklavik
# Processing Record 9 of Set 8 | meoqui
# Processing Record 10 of Set 8 | bubaque
# Processing Record 11 of Set 8 | birjand
# Processing Record 12 of Set 8 | palmer
# Processing Record 13 of Set 8 | general jose eduvigis diaz
# Processing Record 14 of Set 8 | san jose
# Processing Record 15 of Set 8 | edgewater
# Processing Record 16 of Set 8 | marsh harbour
# Processing Record 17 of Set 8 | beringovskiy
# Processing Record 18 of Set 8 | macheng
# Processing Record 19 of Set 8 | verkhniy rohachyk
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | san luis
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | clarence town
# Processing Record 24 of Set 8 | manta
# Processing Record 25 of Set 8 | la gaulette
# City not found. Skipping...
# Processing Record 26 of Set 8 | yumen
# Processing Record 27 of Set 8 | kralendijk
# Processing Record 28 of Set 8 | rawson
# Processing Record 29 of Set 8 | altus
# Processing Record 30 of Set 8 | serang
# Processing Record 31 of Set 8 | narsaq
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | nioki
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | verkhnetulomskiy
# Processing Record 36 of Set 8 | russellville
# Processing Record 37 of Set 8 | dawei
# Processing Record 38 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 8 | atasu
# Processing Record 40 of Set 8 | micheweni
# Processing Record 41 of Set 8 | hambantota
# Processing Record 42 of Set 8 | caconda
# Processing Record 43 of Set 8 | creel
# Processing Record 44 of Set 8 | lompoc
# Processing Record 45 of Set 8 | gornopravdinsk
# Processing Record 46 of Set 8 | ondjiva
# Processing Record 47 of Set 8 | karratha
# Processing Record 48 of Set 8 | teahupoo
# Processing Record 49 of Set 8 | ketchikan
# Processing Record 50 of Set 8 | georgetown
# Processing Record 1 of Set 9 | tasiilaq
# Processing Record 2 of Set 9 | maicao
# Processing Record 3 of Set 9 | breves
# Processing Record 4 of Set 9 | makakilo city
# Processing Record 5 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 6 of Set 9 | biak
# Processing Record 7 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 9 | krasnyy chikoy
# Processing Record 9 of Set 9 | bagdarin
# Processing Record 10 of Set 9 | faanui
# Processing Record 11 of Set 9 | vardo
# Processing Record 12 of Set 9 | saint-pierre
# Processing Record 13 of Set 9 | gewane
# Processing Record 14 of Set 9 | xinzhi
# Processing Record 15 of Set 9 | mujiayingzi
# Processing Record 16 of Set 9 | mokhotlong
# Processing Record 17 of Set 9 | kuminskiy
# Processing Record 18 of Set 9 | barkly west
# Processing Record 19 of Set 9 | kalmunai
# Processing Record 20 of Set 9 | sherghati
# Processing Record 21 of Set 9 | tabou
# Processing Record 22 of Set 9 | los llanos de aridane
# Processing Record 23 of Set 9 | rudnichnyy
# Processing Record 24 of Set 9 | udomlya
# Processing Record 25 of Set 9 | dwarka
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | behbahan
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | constantine
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | meadow lake
# Processing Record 34 of Set 9 | tokmak
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | paulo ramos
# Processing Record 37 of Set 9 | trincomalee
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | akdepe
# Processing Record 40 of Set 9 | waitara
# Processing Record 41 of Set 9 | darnah
# Processing Record 42 of Set 9 | san jeronimo
# Processing Record 43 of Set 9 | tambopata
# Processing Record 44 of Set 9 | tuatapere
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | tubmanburg
# Processing Record 47 of Set 9 | fossombrone
# Processing Record 48 of Set 9 | polson
# Processing Record 49 of Set 9 | port hardy
# Processing Record 50 of Set 9 | byron bay
# Processing Record 1 of Set 10 | ca mau
# Processing Record 2 of Set 10 | leh
# Processing Record 3 of Set 10 | coffs harbour
# Processing Record 4 of Set 10 | susehri
# Processing Record 5 of Set 10 | nuuk
# Processing Record 6 of Set 10 | luganville
# Processing Record 7 of Set 10 | baiyin
# Processing Record 8 of Set 10 | southbridge
# Processing Record 9 of Set 10 | bundaberg
# Processing Record 10 of Set 10 | natal
# Processing Record 11 of Set 10 | bengkulu
# Processing Record 12 of Set 10 | dali
# Processing Record 13 of Set 10 | camopi
# Processing Record 14 of Set 10 | nadym
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | waipawa
# Processing Record 18 of Set 10 | kunda
# Processing Record 19 of Set 10 | colac
# Processing Record 20 of Set 10 | ilam
# Processing Record 21 of Set 10 | dharur
# Processing Record 22 of Set 10 | morbegno
# Processing Record 23 of Set 10 | auki
# Processing Record 24 of Set 10 | kartuzy
# Processing Record 25 of Set 10 | laguna
# Processing Record 26 of Set 10 | nikolsk
# Processing Record 27 of Set 10 | bakau
# Processing Record 28 of Set 10 | limbang
# Processing Record 29 of Set 10 | xichang
# Processing Record 30 of Set 10 | ajaccio
# Processing Record 31 of Set 10 | hearst
# Processing Record 32 of Set 10 | kapasan
# Processing Record 33 of Set 10 | lasa
# Processing Record 34 of Set 10 | tooele
# Processing Record 35 of Set 10 | ugoofaaru
# Processing Record 36 of Set 10 | toyooka
# Processing Record 37 of Set 10 | rosetta
# Processing Record 38 of Set 10 | lebu
# Processing Record 39 of Set 10 | bassila
# Processing Record 40 of Set 10 | bac lieu
# Processing Record 41 of Set 10 | ouadda
# Processing Record 42 of Set 10 | kachiry
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | cortez
# Processing Record 45 of Set 10 | mayo
# Processing Record 46 of Set 10 | paamiut
# Processing Record 47 of Set 10 | matay
# Processing Record 48 of Set 10 | abha
# Processing Record 49 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 10 | valleyview
# Processing Record 1 of Set 11 | sartell
# Processing Record 2 of Set 11 | panixtlahuaca
# City not found. Skipping...
# Processing Record 3 of Set 11 | porto velho
# Processing Record 4 of Set 11 | tura
# Processing Record 5 of Set 11 | kahului
# Processing Record 6 of Set 11 | dubti
# Processing Record 7 of Set 11 | pafos
# Processing Record 8 of Set 11 | acarau
# Processing Record 9 of Set 11 | bandarbeyla
# Processing Record 10 of Set 11 | majene
# Processing Record 11 of Set 11 | tezu
# Processing Record 12 of Set 11 | torit
# Processing Record 13 of Set 11 | kutum
# Processing Record 14 of Set 11 | vyazovaya
# Processing Record 15 of Set 11 | benemerito de las americas
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | batagay-alyta
# Processing Record 18 of Set 11 | tautira
# Processing Record 19 of Set 11 | dodge city
# Processing Record 20 of Set 11 | kloulklubed
# Processing Record 21 of Set 11 | hettstedt
# Processing Record 22 of Set 11 | mattru
# Processing Record 23 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | puerto escondido
# Processing Record 26 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 11 | maningrida
# Processing Record 28 of Set 11 | capul
# Processing Record 29 of Set 11 | saint-georges
# Processing Record 30 of Set 11 | torbay
# Processing Record 31 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 11 | marawi
# Processing Record 33 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 11 | sankheda
# Processing Record 35 of Set 11 | maturin
# Processing Record 36 of Set 11 | hirosaki
# Processing Record 37 of Set 11 | tianpeng
# Processing Record 38 of Set 11 | do rud
# City not found. Skipping...
# Processing Record 39 of Set 11 | haimen
# Processing Record 40 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 11 | davila
# Processing Record 42 of Set 11 | baykit
# Processing Record 43 of Set 11 | pahrump
# Processing Record 44 of Set 11 | rivadavia
# Processing Record 45 of Set 11 | makkaveyevo
# Processing Record 46 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 11 | najran
# Processing Record 48 of Set 11 | vanimo
# Processing Record 49 of Set 11 | arman
# Processing Record 50 of Set 11 | chongwe
# Processing Record 1 of Set 12 | etchoropo
# Processing Record 2 of Set 12 | mangrol
# Processing Record 3 of Set 12 | wick
# Processing Record 4 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 12 | kamloops
# Processing Record 6 of Set 12 | constitucion
# Processing Record 7 of Set 12 | kumher
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | kendari
# Processing Record 10 of Set 12 | sabha
# Processing Record 11 of Set 12 | tatawin
# Processing Record 12 of Set 12 | torres
# Processing Record 13 of Set 12 | beatrice
# Processing Record 14 of Set 12 | khasan
# Processing Record 15 of Set 12 | teknaf
# Processing Record 16 of Set 12 | rujiena
# Processing Record 17 of Set 12 | sorong
# Processing Record 18 of Set 12 | bukoba
# Processing Record 19 of Set 12 | esmeraldas
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | quimper
# Processing Record 22 of Set 12 | ewa beach
# Processing Record 23 of Set 12 | fairbanks
# Processing Record 24 of Set 12 | lujan
# Processing Record 25 of Set 12 | badulla
# Processing Record 26 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 12 | mezen
# Processing Record 28 of Set 12 | primorsk
# Processing Record 29 of Set 12 | saint-joseph
# Processing Record 30 of Set 12 | canto do buriti
# Processing Record 31 of Set 12 | kyren
# Processing Record 32 of Set 12 | bagan
# Processing Record 33 of Set 12 | sistranda
# Processing Record 34 of Set 12 | praia
# Processing Record 35 of Set 12 | meulaboh
# Processing Record 36 of Set 12 | kerchevskiy
# Processing Record 37 of Set 12 | dire dawa
# Processing Record 38 of Set 12 | ola
# Processing Record 39 of Set 12 | deputatskiy
# Processing Record 40 of Set 12 | manali
# Processing Record 41 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 12 | pokanayevka
# City not found. Skipping...
# Processing Record 43 of Set 12 | nelson bay
# Processing Record 44 of Set 12 | masakin
# Processing Record 45 of Set 12 | kansk
# Processing Record 46 of Set 12 | souillac
# Processing Record 47 of Set 12 | acari
# Processing Record 48 of Set 12 | trofors
# Processing Record 49 of Set 12 | luau
# Processing Record 50 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | okha
# Processing Record 2 of Set 13 | brae
# Processing Record 3 of Set 13 | inuvik
# Processing Record 4 of Set 13 | karasburg
# Processing Record 5 of Set 13 | kurchum
# Processing Record 6 of Set 13 | progreso
# Processing Record 7 of Set 13 | ginda
# Processing Record 8 of Set 13 | gurupa
# Processing Record 9 of Set 13 | san vicente
# Processing Record 10 of Set 13 | severnoye
# Processing Record 11 of Set 13 | uk
# City not found. Skipping...
# Processing Record 12 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 13 | ulaangom
# Processing Record 14 of Set 13 | muhos
# Processing Record 15 of Set 13 | santa cruz del sur
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | qarqin
# Processing Record 18 of Set 13 | nacala
# Processing Record 19 of Set 13 | port moresby
# Processing Record 20 of Set 13 | srednekolymsk
# Processing Record 21 of Set 13 | maraial
# Processing Record 22 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 23 of Set 13 | kibala
# Processing Record 24 of Set 13 | ocampo
# Processing Record 25 of Set 13 | adrar
# Processing Record 26 of Set 13 | araouane
# Processing Record 27 of Set 13 | russell
# Processing Record 28 of Set 13 | boatlaname
# City not found. Skipping...
# Processing Record 29 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 13 | finnsnes
# Processing Record 31 of Set 13 | tarut
# Processing Record 32 of Set 13 | manaure
# Processing Record 33 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 13 | iberia
# Processing Record 35 of Set 13 | pontecorvo
# Processing Record 36 of Set 13 | smirnykh
# Processing Record 37 of Set 13 | misratah
# Processing Record 38 of Set 13 | simao
# Processing Record 39 of Set 13 | camargo
# Processing Record 40 of Set 13 | sopelana
# Processing Record 41 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 13 | jacareacanga
# Processing Record 43 of Set 13 | gloversville
# Processing Record 44 of Set 13 | maumere
# Processing Record 45 of Set 13 | buala
# Processing Record 46 of Set 13 | duayaw nkwanta
# Processing Record 47 of Set 13 | shcholkine
# City not found. Skipping...
# Processing Record 48 of Set 13 | vagamo
# Processing Record 49 of Set 13 | carauari
# Processing Record 50 of Set 13 | huntington
# Processing Record 1 of Set 14 | college
# Processing Record 2 of Set 14 | bethel
# Processing Record 3 of Set 14 | nhamunda
# Processing Record 4 of Set 14 | pierre
# Processing Record 5 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 14 | shorapur
# Processing Record 7 of Set 14 | riachao
# Processing Record 8 of Set 14 | shahr-e babak
# Processing Record 9 of Set 14 | diffa
# Processing Record 10 of Set 14 | xining
# Processing Record 11 of Set 14 | south valley
# Processing Record 12 of Set 14 | noyabrsk
# Processing Record 13 of Set 14 | weligama
# Processing Record 14 of Set 14 | les cayes
# Processing Record 15 of Set 14 | lipin bor
# Processing Record 16 of Set 14 | seoul
# Processing Record 17 of Set 14 | wufeng
# Processing Record 18 of Set 14 | pravia
# Processing Record 19 of Set 14 | bosaso
# Processing Record 20 of Set 14 | erzin
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | road town
# Processing Record 23 of Set 14 | kargasok
# Processing Record 24 of Set 14 | lahij
# Processing Record 25 of Set 14 | sioux lookout
# Processing Record 26 of Set 14 | sovetskiy
# Processing Record 27 of Set 14 | naifaru
# Processing Record 28 of Set 14 | gualeguay
# Processing Record 29 of Set 14 | sao filipe
# Processing Record 30 of Set 14 | noumea
# Processing Record 31 of Set 14 | puerto del rosario
# Processing Record 32 of Set 14 | beyneu
# Processing Record 33 of Set 14 | khapa
# Processing Record 34 of Set 14 | tonj
# Processing Record 35 of Set 14 | oda
# Processing Record 36 of Set 14 | lewistown
# Processing Record 37 of Set 14 | goderich
# Processing Record 38 of Set 14 | darhan
# Processing Record 39 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 14 | camacha
# Processing Record 41 of Set 14 | krasnoselkup
# Processing Record 42 of Set 14 | nemuro
# Processing Record 43 of Set 14 | alofi
# Processing Record 44 of Set 14 | north platte
# Processing Record 45 of Set 14 | jardim
# Processing Record 46 of Set 14 | santarem
# Processing Record 47 of Set 14 | cartagena
# Processing Record 48 of Set 14 | soe
# Processing Record 49 of Set 14 | wright
# Processing Record 50 of Set 14 | santa vitoria do palmar
# Processing Record 1 of Set 15 | puksoozero
# Processing Record 2 of Set 15 | champerico
# Processing Record 3 of Set 15 | hurghada
# Processing Record 4 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 15 | pasighat
# Processing Record 6 of Set 15 | ilhabela
# Processing Record 7 of Set 15 | enkoping
# Processing Record 8 of Set 15 | northam
# Processing Record 9 of Set 15 | saint-pascal
# City not found. Skipping...
# Processing Record 10 of Set 15 | matara
# Processing Record 11 of Set 15 | troitsko-pechorsk
# Processing Record 12 of Set 15 | grafton
# Processing Record 13 of Set 15 | simpang
# Processing Record 14 of Set 15 | launceston
# Processing Record 15 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 16 of Set 15 | huarmey
# Processing Record 17 of Set 15 | le port
# Processing Record 18 of Set 15 | henties bay
# Processing Record 19 of Set 15 | iskateley
# Processing Record 20 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 15 | ambunti
# Processing Record 22 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 15 | pringsewu
# Processing Record 24 of Set 15 | mukhen
# Processing Record 25 of Set 15 | puerto carreno
# Processing Record 26 of Set 15 | santa fe
# Processing Record 27 of Set 15 | kamenka
# Processing Record 28 of Set 15 | zinder
# Processing Record 29 of Set 15 | barao de melgaco
# Processing Record 30 of Set 15 | dinghai
# Processing Record 31 of Set 15 | blois
# Processing Record 32 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 33 of Set 15 | hargeysa
# Processing Record 34 of Set 15 | kenora
# Processing Record 35 of Set 15 | fushun
# Processing Record 36 of Set 15 | aswan
# Processing Record 37 of Set 15 | shenjiamen
# Processing Record 38 of Set 15 | mountain home
# Processing Record 39 of Set 15 | crotone
# Processing Record 40 of Set 15 | bismarck
# Processing Record 41 of Set 15 | verkhnyaya inta
# Processing Record 42 of Set 15 | roebourne
# Processing Record 43 of Set 15 | mazara del vallo
# Processing Record 44 of Set 15 | nabire
# Processing Record 45 of Set 15 | pennagaram
# Processing Record 46 of Set 15 | lesnoy
# Processing Record 47 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 15 | karatau
# Processing Record 49 of Set 15 | saint-augustin
# Processing Record 50 of Set 15 | ambilobe
# Processing Record 1 of Set 16 | newport
# Processing Record 2 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 16 | loandjili
# Processing Record 4 of Set 16 | gedo
# Processing Record 5 of Set 16 | rodeo
# Processing Record 6 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 16 | kalabugao
# City not found. Skipping...
# Processing Record 8 of Set 16 | manggar
# Processing Record 9 of Set 16 | toora-khem
# Processing Record 10 of Set 16 | cody
# Processing Record 11 of Set 16 | kushiro
# Processing Record 12 of Set 16 | alugan
# Processing Record 13 of Set 16 | severo-kurilsk
# Processing Record 14 of Set 16 | wisconsin rapids
# Processing Record 15 of Set 16 | tagbac
# Processing Record 16 of Set 16 | dondo
# Processing Record 17 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 16 | monrovia
# Processing Record 19 of Set 16 | anchorage
# Processing Record 20 of Set 16 | amapa
# Processing Record 21 of Set 16 | agbor
# Processing Record 22 of Set 16 | buluang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mar Del Plata -38.0023  -57.5575     51.10        94          81
# 1        Zhigansk  66.7697  123.3711     72.18        51          25
# 2     Tuktoyaktuk  69.4541 -133.0374     39.29        84          46
# 3  Port Elizabeth -33.9180   25.5701     50.09        67          81
# 4        Mahdasht  35.7299   50.8111     82.62        45           4
# 5  Konstantinovka  49.6167  127.9833     84.85        43          19
# 6  Saint-Philippe -21.3585   55.7679     74.21        74          17
# 7       Esperance -33.8667  121.9000     61.63        48           1
# 8    Ponta Do Sol  32.6667  -17.1000     84.83        40          28
# 9           Vaini -21.2000 -175.2000     72.46        68          48
#
#    Wind Speed Country Current Description
# 0        4.00      AR       broken clouds
# 1        3.40      RU    scattered clouds
# 2        7.54      CA    scattered clouds
# 3        4.92      ZA       broken clouds
# 4       19.84      IR           clear sky
# 5        6.82      RU          few clouds
# 6        8.19      RE          light rain
# 7       14.45      AU           clear sky
# 8        4.23      PT    scattered clouds
# 9       20.54      TO    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mar Del Plata      AR -38.0023  -57.5575     51.10        94          81
# 1        Zhigansk      RU  66.7697  123.3711     72.18        51          25
# 2     Tuktoyaktuk      CA  69.4541 -133.0374     39.29        84          46
# 3  Port Elizabeth      ZA -33.9180   25.5701     50.09        67          81
# 4        Mahdasht      IR  35.7299   50.8111     82.62        45           4
# 5  Konstantinovka      RU  49.6167  127.9833     84.85        43          19
# 6  Saint-Philippe      RE -21.3585   55.7679     74.21        74          17
# 7       Esperance      AU -33.8667  121.9000     61.63        48           1
# 8    Ponta Do Sol      PT  32.6667  -17.1000     84.83        40          28
# 9           Vaini      TO -21.2000 -175.2000     72.46        68          48
#
#    Wind Speed Current Description
# 0        4.00       broken clouds
# 1        3.40    scattered clouds
# 2        7.54    scattered clouds
# 3        4.92       broken clouds
# 4       19.84           clear sky
# 5        6.82          few clouds
# 6        8.19          light rain
# 7       14.45           clear sky
# 8        4.23    scattered clouds
# 9       20.54    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the file into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
